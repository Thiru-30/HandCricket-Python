# %%
import random
num=[1,2,3,4,5,6]

def userbatting():
  user_score=0
  while(True):
    user_run=int(input("Enter your run "))
    if(user_run in num):
      computer_run = random.choice(num)
      print("Computer run is ",computer_run)
      if(user_run == computer_run):
        print("You are out!")
        print("The total score is",user_score)
        print("User bowling::")
        break
      else:
        user_score += user_run    


  computer_score=0
  while(True):
    computer_run=random.choice(num)
    user_run=int(input("Enter your run(bowling) "))
    print("Computer run is ",computer_run)
    if(user_run in num):
      if(computer_run==user_run):
        print("Computer is out!")
        print("Computer score is ",computer_score)
        if(user_score>computer_score):
          print("User Won the match")
          break
        elif(user_score==computer_score):
          print("Draw match")
          break
      else:
        computer_score=computer_score+computer_run
        if(computer_score>user_score):
          print("Computer won the match")
          break


def compbatting():
  computer_score=0
  while(True):
    user_run=int(input("Enter your run(bowling) "))
    if(user_run in num):
      computer_run = random.choice(num)
      print("Computer run is ",computer_run)
      if(user_run == computer_run):
        print("Computer is out!")
        print("The total target is",computer_score)
        print("User batting::")
        break
      else:
        computer_score += computer_run    


  user_score=0
  while(True):
    computer_run=random.choice(num)
    user_run=int(input("Enter your run "))
    print("Computer run is ",computer_run)
    if(user_run in num):
      if(computer_run==user_run):
        print("User is out!")
        print("User score is ",user_score)
        if(user_score<computer_score):
          print("Computer Won the match")
        elif(user_score==computer_score):
          print("Draw match")
          break
      else:
        user_score+=user_run
        if(user_score>computer_score):
          print("User won the match")
          break




# Game Begins Here      
while(True):
  toss=int(input("1 for ODD: 0 for EVEN "))
  if(toss==0 or toss==1):
    while(True):
      toss_user=int(input("Enter for TOSS "))
      if(toss_user in num):
        toss_com=random.choice(num)
        print("Computer choice for toss is ",toss_com)
        toss_total=toss_user+toss_com
        toss_result=toss_total%2
        if(toss==toss_result):
          print("You have won the toss.")
          user_ch=int(input("Enter your decision: 1 for Batting::2 for Bowling "))
          if(user_ch==1):
            userbatting()
            break
          elif(user_ch==2):
            compbatting()
            break
        else:
          print("Computer won the toss")
          toss_choices=[1,2]
          com_ch=random.choice(toss_choices)
          if(com_ch==1):
            print("Computer chose Batting.")
            compbatting()
            break
          else:
            print("Computer choose Bowling.")
            userbatting()
            break
        break
    break
